# %%
import math
data = {
	'Alan Perlis': { 
		'Artificial intelligence': 1.46, 
		'Systems programming': 5.0, 
		'Software engineering': 3.34, 
		'Databases': 2.32
	},

	'Marvin Minsky': { 
		'Artificial intelligence': 5.0, 
		'Systems programming': 2.54,
		'Computation': 4.32, 
		'Algorithms': 2.76
	},

	'John McCarthy': { 
		'Artificial intelligence': 5.0, 
		'Programming language theory': 4.72, 
		'Systems programming': 3.25, 
		'Concurrency': 3.61, 
		'Formal methods': 3.58,
		'Computation': 3.23, 
		'Algorithms': 3.03 
	},

	'Edsger Dijkstra': { 
		'Programming language theory': 4.34, 
		'Systems programming': 4.52,
		'Software engineering': 4.04, 
		'Concurrency': 3.97,
		'Formal methods': 5.0, 
		'Algorithms': 4.92 
	},

	'Donald Knuth': { 
		'Programming language theory': 4.33, 
		'Systems programming': 3.57,
		'Computation': 4.39, 
		'Algorithms': 5.0 
	},

	'John Backus': { 
		'Programming language theory': 4.58, 
		'Systems programming': 4.43,
		'Software engineering': 4.38, 
		'Formal methods': 2.42, 
		'Databases': 2.80 
	},

	'Robert Floyd': { 
		'Programming language theory': 4.24, 
		'Systems programming': 2.17,
		'Concurrency': 2.92, 
		'Formal methods': 5.0, 
		'Computation': 3.18, 
		'Algorithms': 5.0 
	},

	'Tony Hoare': { 
		'Programming language theory': 4.64, 
		'Systems programming': 4.38,
		'Software engineering': 3.62, 
		'Concurrency': 4.88,
		'Formal methods': 4.72, 
		'Algorithms': 4.38
	},

	'Edgar Codd': { 
		'Systems programming': 4.60, 
		'Software engineering': 3.54,
		'Concurrency': 4.28, 
		'Formal methods': 1.53, 
		'Databases': 5.0
	},

	'Dennis Ritchie': { 
		'Programming language theory': 3.45, 
		'Systems programming': 5.0,
		'Software engineering': 4.83,
	},

	'Niklaus Wirth': { 
		'Programming language theory': 4.23, 
		'Systems programming': 4.22,
		'Software engineering': 4.74, 
		'Formal methods': 3.83, 
		'Algorithms': 3.95
	},

	'Robin Milner': { 
		'Programming language theory': 5.0, 
		'Systems programming': 1.66,
		'Concurrency': 4.62, 
		'Formal methods': 3.94,
	},

	'Leslie Lamport': { 
		'Programming language theory': 1.5, 
		'Systems programming': 2.76,
		'Software engineering': 3.76, 
		'Concurrency': 5.0,
		'Formal methods': 4.93, 
		'Algorithms': 4.63
	},

	'Michael Stonebraker': { 
		'Systems programming': 4.67, 
		'Software engineering': 3.86,
		'Concurrency': 4.14, 
		'Databases': 5.0,
	},
}
import pandas as pd
ratings = pd.read_csv("/home/jinghong/Recommendation_System/rate_table.csv",header = 0)
name = ["ItemID","Ad_waist","Durability","Purchase_price","Selling_price","Origin_name","Image", \
 "Is_Organic","Bloomers","DrawString","Softness","Min_Temp","Max_Temp","CreatedAt","UpdatedAt","BrandID","CountOrigID", \
 "GenderID","MaterialID","PatternID","WID","DID","DCID","OTID","GenusID","CutID","DTID","NeckID","OPBID","OPTID",\
 "OPTYID","Pant_TypeID","STID","Skirt_lengthID","Skirt_TypeID","SleeveID","Brand_Sku"]
items_data = pd.read_csv("/home/jinghong/Recommendation_System/items.csv",names=name)
rating_dict = {}
for index,row in ratings.iterrows():
    if(math.isnan(row['Style Rating'])):
        continue
    if row['User #'] in rating_dict:
        rating_dict[row['User #']][row['Item ID']] = row['Style Rating']
    else:
        rating_dict[row['User #']] = {}
        rating_dict[row['User #']][row['Item ID']] = row['Style Rating']
data = rating_dict

# %%
def pearson_similarity(person1,person2):
    common_ranked_items = [item for item in data[person1] if item in data[person2]]
    n = len(common_ranked_items)
    s1 = sum(data[person1][item] for item in common_ranked_items)
    s2 = sum(data[person2][item] for item in common_ranked_items)
    ss1 = sum(pow(data[person1][item],2) for item in common_ranked_items)
    ss2 = sum(pow(data[person2][item],2) for item in common_ranked_items)
    ps = sum(data[person1][item] * data[person2][item] for item in common_ranked_items)
    num = n* ps - (s1*s2)
    den = math.sqrt((n*ss1 - math.pow(s1,2)) * (n*ss2 - math.pow(s2,2)))
    return (num/den) if den != 0 else 0

# %%
def euclidean_similarity(person1, person2):
    common_ranked_items = [itm for itm in data[person1] if itm in data[person2]]
    rankings = [(data[person1][itm], data[person2][itm]) for itm in common_ranked_items]
    distance = [pow(rank[0] - rank[1], 2) for rank in rankings]
    if(len(common_ranked_items) == 0):
        return 0
    return 1 / (1 + sum(distance))
# Out:
#   File "<ipython-input-32-81b4f0515fbc>", line 5
#     if(len(common_ranked_items) == 0)
#                                      ^
# SyntaxError: invalid syntax

# %%
def recommend(person, bound, similarity=pearson_similarity):
    scores = [(similarity(person, other), other) for other in data if other != person]
    scores.sort()
    scores.reverse()
    scores = scores[0:bound]
    recomms = {}
    for sim, other in scores:
        ranked = data[other]
        for itm in ranked:
            if itm not in data[person]:
                weight = sim * ranked[itm]
                if itm in recomms:
                    s, weights = recomms[itm]
                    recomms[itm] = (s + sim, weights + [weight])
                else:
                    recomms[itm] = (sim, [weight])
    for r in recomms:
        sim, item = recomms[r]
        recomms[r] = sum(item) / sim
    mydict = { k:v for k,v in recomms.items() if math.isnan(v) == False}
    return mydict
items = recommend(5,10, euclidean_similarity)

# %%
sorted_items = [(k,items[k]) for k in sorted(items,key=items.get,reverse=True)]
for item in sorted_items:
    print(items_data.loc[items_data['ItemID'] == int(item[0])])
# Out:
#     ItemID Ad_waist  Durability Purchase_price Selling_price  Origin_name  \
# 17      23       No           5           2.21        100.00  Anais and I
#
#                                                 Image Is_Organic Bloomers  \
# 17  https://upload.wikimedia.org/wikipedia/commons...         No       \N
#
#    DrawString    ...      NeckID  OPBID  OPTID OPTYID Pant_TypeID  STID  \
# 17         \N    ...          \N     \N     \N     \N           6    \N
#
#     Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 17              \N            \N        \N         \N
#
# [1 rows x 37 columns]
#     ItemID Ad_waist  Durability Purchase_price Selling_price  \
# 20      26      NaN           2           2.21         99.00
#
#            Origin_name                                              Image  \
# 20  Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
#
#    Is_Organic Bloomers DrawString    ...      NeckID  OPBID  OPTID OPTYID  \
# 20        Yes       \N         \N    ...           1     \N     \N     \N
#
#    Pant_TypeID  STID  Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 20          \N    \N              \N            \N         4         \N
#
# [1 rows x 37 columns]
#    ItemID Ad_waist  Durability Purchase_price Selling_price   Origin_name  \
# 0       1      Yes           4           2.21         39.00  A&I Closeout
#
#                                                Image Is_Organic Bloomers  \
# 0  https://upload.wikimedia.org/wikipedia/commons...         No       \N
#
#   DrawString    ...      NeckID  OPBID  OPTID OPTYID Pant_TypeID  STID  \
# 0         No    ...          \N     \N     \N     \N          \N    \N
#
#    Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 0               2             5        \N         \N
#
# [1 rows x 37 columns]
#    ItemID Ad_waist  Durability Purchase_price Selling_price    Origin_name  \
# 2       7      Yes           2           2.21         90.00  A&I close out
#
#                                                Image Is_Organic Bloomers  \
# 2  https://upload.wikimedia.org/wikipedia/commons...         No       \N
#
#   DrawString    ...      NeckID  OPBID  OPTID OPTYID Pant_TypeID  STID  \
# 2        Yes    ...          \N     \N     \N     \N           1    \N
#
#    Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 2              \N            \N        \N         \N
#
# [1 rows x 37 columns]
# Empty DataFrame
# Columns: [ItemID, Ad_waist, Durability, Purchase_price, Selling_price, Origin_name, Image, Is_Organic, Bloomers, DrawString, Softness, Min_Temp, Max_Temp, CreatedAt, UpdatedAt, BrandID, CountOrigID, GenderID, MaterialID, PatternID, WID, DID, DCID, OTID, GenusID, CutID, DTID, NeckID, OPBID, OPTID, OPTYID, Pant_TypeID, STID, Skirt_lengthID, Skirt_TypeID, SleeveID, Brand_Sku]
# Index: []
#
# [0 rows x 37 columns]
# Empty DataFrame
# Columns: [ItemID, Ad_waist, Durability, Purchase_price, Selling_price, Origin_name, Image, Is_Organic, Bloomers, DrawString, Softness, Min_Temp, Max_Temp, CreatedAt, UpdatedAt, BrandID, CountOrigID, GenderID, MaterialID, PatternID, WID, DID, DCID, OTID, GenusID, CutID, DTID, NeckID, OPBID, OPTID, OPTYID, Pant_TypeID, STID, Skirt_lengthID, Skirt_TypeID, SleeveID, Brand_Sku]
# Index: []
#
# [0 rows x 37 columns]
#    ItemID Ad_waist  Durability Purchase_price Selling_price    Origin_name  \
# 1       4      Yes           4           2.21         55.00  A&I close out
#
#                                                Image Is_Organic Bloomers  \
# 1  https://upload.wikimedia.org/wikipedia/commons...         No       \N
#
#   DrawString    ...      NeckID  OPBID  OPTID OPTYID Pant_TypeID  STID  \
# 1        Yes    ...          \N     \N     \N     \N           3    \N
#
#    Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 1              \N            \N        \N         \N
#
# [1 rows x 37 columns]
#     ItemID Ad_waist  Durability Purchase_price Selling_price   Origin_name  \
# 16      22      NaN           3          00.00         75.00  A&I Closeout
#
#                                                 Image Is_Organic Bloomers  \
# 16  https://upload.wikimedia.org/wikipedia/commons...         No       \N
#
#    DrawString    ...      NeckID  OPBID  OPTID OPTYID Pant_TypeID  STID  \
# 16         \N    ...           8     \N     \N     \N          \N    \N
#
#     Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 16              \N            \N         4     K10000
#
# [1 rows x 37 columns]
# Empty DataFrame
# Columns: [ItemID, Ad_waist, Durability, Purchase_price, Selling_price, Origin_name, Image, Is_Organic, Bloomers, DrawString, Softness, Min_Temp, Max_Temp, CreatedAt, UpdatedAt, BrandID, CountOrigID, GenderID, MaterialID, PatternID, WID, DID, DCID, OTID, GenusID, CutID, DTID, NeckID, OPBID, OPTID, OPTYID, Pant_TypeID, STID, Skirt_lengthID, Skirt_TypeID, SleeveID, Brand_Sku]
# Index: []
#
# [0 rows x 37 columns]
#     ItemID Ad_waist  Durability Purchase_price Selling_price  Origin_name  \
# 18      24       No           5           2.21         64.00  Anais and I
#
#                                                 Image Is_Organic Bloomers  \
# 18  https://upload.wikimedia.org/wikipedia/commons...         No       \N
#
#    DrawString    ...      NeckID  OPBID  OPTID OPTYID Pant_TypeID  STID  \
# 18         \N    ...          \N     \N     \N     \N          \N     3
#
#     Skirt_lengthID  Skirt_TypeID  SleeveID  Brand_Sku
# 18              \N            \N        \N         \N
#
# [1 rows x 37 columns]
# ---------------------------------------------------------------------
# ValueError                          Traceback (most recent call last)
# <ipython-input-30-d1b55db3f893> in <module>()
#       1 sorted_items = [(k,items[k]) for k in sorted(items,key=items.get,reverse=True)]
#       2 for item in sorted_items:
# ----> 3     print(items_data.loc[items_data['ItemID'] == int(item[0])])
#
# ValueError: invalid literal for int() with base 10: 'x'

# %%
items_data
# Out:
#      ItemID Ad_waist  Durability Purchase_price Selling_price  \
# 0         1      Yes           4           2.21         39.00
# 1         4      Yes           4           2.21         55.00
# 2         7      Yes           2           2.21         90.00
# 3         8      Yes           4           2.21         78.00
# 4         9      Yes           3           2.21         -1.00
# 5        10      Yes           4           2.21        118.00
# 6        11      Yes           4           2.21        119.00
# 7        13      NaN           4          00.00         32.00
# 8        14      NaN           3          00.00         -1.00
# 9        15      NaN           2           2.21         -1.00
# 10       16      Yes           4           2.21         -1.00
# 11       17      Yes           4           2.21         -1.00
# 12       18      Yes           3          00.00         96.00
# 13       19       No           3          00.00         -1.00
# 14       20       No           3          00.00        107.00
# 15       21       No           2          00.00        107.00
# 16       22      NaN           3          00.00         75.00
# 17       23       No           5           2.21        100.00
# 18       24       No           5           2.21         64.00
# 19       25      Yes           4           2.21        100.00
# 20       26      NaN           2           2.21         99.00
# 21       27      Yes           2           2.21         79.00
# 22       28      Yes           5          00.00         30.00
# 23       29      Yes           5          00.00         78.00
# 24       30      Yes           2           2.21         79.00
# 25       31       No           5           2.21        100.00
# 26       32       No           5           2.21        100.00
# 27       33      Yes           2           2.21         79.00
# 28       34      Yes           2           2.21         79.00
# 29       35      Yes           3           2.21         79.00
# ..      ...      ...         ...            ...           ...
# 214     233      Yes           2           2.21         64.00
# 215     234       No           2           2.21         48.00
# 216     235       No           3          00.00         78.00
# 217     236      Yes           4           5.00         94.00
# 218     237      Yes           4          00.00         57.00
# 219     238      NaN           4          00.00         79.00
# 220     239      NaN           1           2.21         55.00
# 221     240      NaN           4           6.00         30.00
# 222     241      NaN           3           6.00         32.00
# 223     242      NaN           3           4.00         70.00
# 224     243      NaN           2           2.21         68.00
# 225     244      NaN           3       19000.00         82.00
# 226     245      NaN           3          00.00         49.00
# 227     246      NaN           5       19000.00         86.00
# 228     247       No           3          00.00         35.00
# 229     248      NaN           3           5.00         27.95
# 230     249      NaN           3           4.00         30.00
# 231     250      NaN           3           5.00         13.00
# 232     251      NaN           3          00.00         80.00
# 233     252      Yes           1           4.00         28.00
# 234     253      Yes           3          00.00         68.00
# 235     254      Yes           4           2.21         86.00
# 236     255      Yes           3          00.00         28.00
# 237     256      Yes           3          10.00         48.00
# 238     257       No           4          00.00         49.50
# 239     258       No           4           2.21         65.00
# 240     259      NaN           2           6.00         38.00
# 241     260      Yes           3           2.21         -1.00
# 242     261      NaN           3           2.21         99.00
# 243     262       No           5           2.21         -1.00
#
#               Origin_name                                              Image  \
# 0            A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 1           A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 2           A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 3            A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 4            A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 5           A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 6            A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 7        Luxaby close out  https://upload.wikimedia.org/wikipedia/commons...
# 8        Luxaby close out  https://upload.wikimedia.org/wikipedia/commons...
# 9           A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 10          A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 11          A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 12           A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 13           A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 14           A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 15           A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 16           A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 17            Anais and I  https://upload.wikimedia.org/wikipedia/commons...
# 18            Anais and I  https://upload.wikimedia.org/wikipedia/commons...
# 19              Anais & I  https://upload.wikimedia.org/wikipedia/commons...
# 20     Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 21     Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 22                 Luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 23                 Luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 24     Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 25            Anais and I  https://upload.wikimedia.org/wikipedia/commons...
# 26            Anais and I  https://upload.wikimedia.org/wikipedia/commons...
# 27     Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 28     Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 29     Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# ..                    ...                                                ...
# 214    Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 215    Anais & I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 216                Luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 217            Phisticate  https://upload.wikimedia.org/wikipedia/commons...
# 218      Proof of Concept  https://upload.wikimedia.org/wikipedia/commons...
# 219                Luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 220    AnaisandI CloseOut  https://upload.wikimedia.org/wikipedia/commons...
# 221         Private Label  https://upload.wikimedia.org/wikipedia/commons...
# 222         private label  https://upload.wikimedia.org/wikipedia/commons...
# 223        Bunny's Picnic  https://upload.wikimedia.org/wikipedia/commons...
# 224         A&I close out  https://upload.wikimedia.org/wikipedia/commons...
# 225       Luxaby CloseOut  https://upload.wikimedia.org/wikipedia/commons...
# 226       luxaby closeout  https://upload.wikimedia.org/wikipedia/commons...
# 227       Luxaby CloseOut  https://upload.wikimedia.org/wikipedia/commons...
# 228       Luxaby CloseOut  https://upload.wikimedia.org/wikipedia/commons...
# 229    ECOMMERCE PURCHASE  https://upload.wikimedia.org/wikipedia/commons...
# 230         Bunnys Picnic  https://upload.wikimedia.org/wikipedia/commons...
# 231    ECOMMERCE PURCHASE  https://upload.wikimedia.org/wikipedia/commons...
# 232       luxaby closeout  https://upload.wikimedia.org/wikipedia/commons...
# 233        Bunnies Picnic  https://upload.wikimedia.org/wikipedia/commons...
# 234                Luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 235  Anais and I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 236                Luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 237  Sample Sale Goodwill  https://upload.wikimedia.org/wikipedia/commons...
# 238                luxaby  https://upload.wikimedia.org/wikipedia/commons...
# 239          A&I CLOSEOUT  https://upload.wikimedia.org/wikipedia/commons...
# 240         Private Label  https://upload.wikimedia.org/wikipedia/commons...
# 241          A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 242          A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
# 243          A&I Closeout  https://upload.wikimedia.org/wikipedia/commons...
#
#     Is_Organic Bloomers DrawString               ...                 NeckID  \
# 0           No       \N         No               ...                     \N
# 1           No       \N        Yes               ...                     \N
# 2           No       \N        Yes               ...                     \N
# 3           No       \N         No               ...                     \N
# 4           No       \N         No               ...                     \N
# 5           No       \N        Yes               ...                     \N
# 6           No       \N         No               ...                     \N
# 7           No       \N         \N               ...                     14
# 8           No       \N         \N               ...                      3
# 9           No       \N         \N               ...                     14
# 10          No       \N         No               ...                     \N
# 11          No       \N         No               ...                     \N
# 12          No       \N         No               ...                     \N
# 13          No       \N         No               ...                     \N
# 14          No       \N         No               ...                     \N
# 15          No       \N         \N               ...                      3
# 16          No       \N         \N               ...                      8
# 17          No       \N         \N               ...                     \N
# 18          No       \N         \N               ...                     \N
# 19          No       \N         \N               ...                     \N
# 20         Yes       \N         \N               ...                      1
# 21          No       No         \N               ...                     \N
# 22          No       \N         \N               ...                     \N
# 23          No       \N         \N               ...                     \N
# 24          No       \N         \N               ...                     \N
# 25          No       \N         \N               ...                     \N
# 26          No       \N         \N               ...                     \N
# 27          No       \N         \N               ...                     \N
# 28          No       \N         \N               ...                     \N
# 29          No       \N         \N               ...                     \N
# ..         ...      ...        ...               ...                    ...
# 214         No       \N         \N               ...                     \N
# 215         No       \N         \N               ...                      4
# 216         No       \N         \N               ...                     14
# 217         No       \N         \N               ...                      9
# 218         No       \N         \N               ...                     \N
# 219         No       \N         \N               ...                     14
# 220         No       \N         \N               ...                     15
# 221        Yes       \N         \N               ...                      3
# 222         No       \N         \N               ...                      1
# 223         No       No         \N               ...                     \N
# 224         No       \N         \N               ...                     14
# 225         No       \N         \N               ...                      2
# 226         No       \N         \N               ...                     14
# 227         No       \N         \N               ...                      3
# 228         No       No         \N               ...                     \N
# 229        Yes       \N         \N               ...                      3
# 230         No       \N         \N               ...                     14
# 231        Yes       \N         \N               ...                      1
# 232         No       \N         \N               ...                     14
# 233         No       \N         \N               ...                     \N
# 234         No       \N         \N               ...                     \N
# 235         No       \N         \N               ...                     \N
# 236         No       \N         \N               ...                     \N
# 237         No       \N         \N               ...                     \N
# 238         No       \N         \N               ...                     \N
# 239         No       \N         \N               ...                     \N
# 240        Yes       \N         \N               ...                      3
# 241         No       \N         \N               ...                     \N
# 242         No       \N         \N               ...                      1
# 243         No       \N         \N               ...                     \N
#
#      OPBID  OPTID OPTYID Pant_TypeID  STID  Skirt_lengthID  Skirt_TypeID  \
# 0       \N     \N     \N          \N    \N               2             5
# 1       \N     \N     \N           3    \N              \N            \N
# 2       \N     \N     \N           1    \N              \N            \N
# 3       \N     \N     \N          \N    \N              \N            \N
# 4       \N     \N     \N           3    \N              \N            \N
# 5       \N     \N     \N           7    \N              \N            \N
# 6       \N     \N     \N          \N     3              \N            \N
# 7       \N     \N     \N          \N    \N              \N            \N
# 8       \N     \N     \N          \N    \N              \N            \N
# 9       \N     \N     \N          \N    \N              \N            \N
# 10      \N     \N     \N          \N    \N              \N            \N
# 11      \N     \N     \N          \N     3              \N            \N
# 12      \N     \N     \N          \N    \N               2             3
# 13      \N     \N     \N          \N     3              \N            \N
# 14      \N     \N     \N           7    \N              \N            \N
# 15      \N     \N     \N          \N    \N              \N            \N
# 16      \N     \N     \N          \N    \N              \N            \N
# 17      \N     \N     \N           6    \N              \N            \N
# 18      \N     \N     \N          \N     3              \N            \N
# 19      \N     \N     \N           8    \N              \N            \N
# 20      \N     \N     \N          \N    \N              \N            \N
# 21      \N     \N     \N          \N    \N              \N            \N
# 22      \N     \N     \N           6    \N              \N            \N
# 23      \N     \N     \N           6    \N              \N            \N
# 24      \N     \N     \N          \N    \N              \N            \N
# 25      \N     \N     \N           6    \N              \N            \N
# 26      \N     \N     \N           6    \N              \N            \N
# 27      \N     \N     \N          \N     3              \N            \N
# 28      \N     \N     \N          \N     3              \N            \N
# 29      \N     \N     \N           2    \N              \N            \N
# ..     ...    ...    ...         ...   ...             ...           ...
# 214     \N     \N     \N          \N    \N               1             3
# 215     \N     \N     \N          \N    \N              \N            \N
# 216     \N     \N     \N          \N    \N              \N            \N
# 217     \N     \N     \N          \N    \N              \N            \N
# 218     \N     \N     \N          \N    \N               2             5
# 219     \N     \N     \N          \N    \N              \N            \N
# 220     \N     \N     \N          \N    \N              \N            \N
# 221     \N     \N     \N          \N    \N              \N            \N
# 222     \N     \N     \N          \N    \N              \N            \N
# 223     \N     \N     \N          \N    \N              \N            \N
# 224     \N     \N     \N          \N    \N              \N            \N
# 225     \N     \N     \N          \N    \N              \N            \N
# 226     \N     \N     \N          \N    \N              \N            \N
# 227     \N     \N     \N          \N    \N              \N            \N
# 228     \N     \N     \N          \N    \N              \N            \N
# 229     \N     \N     \N          \N    \N              \N            \N
# 230     \N     \N     \N          \N    \N              \N            \N
# 231     \N     \N     \N          \N    \N              \N            \N
# 232     \N     \N     \N          \N    \N              \N            \N
# 233     \N     \N     \N          \N    \N              \N            \N
# 234     \N     \N     \N          \N    \N              \N            \N
# 235     \N     \N      7          \N    \N              \N            \N
# 236     \N     \N     \N          \N    \N              \N            \N
# 237     \N     \N     \N          \N     7              \N            \N
# 238     \N     \N     \N           8    \N              \N            \N
# 239     \N     \N     \N          \N     3              \N            \N
# 240     \N     \N     \N          \N    \N              \N            \N
# 241     \N     \N     \N           3    \N              \N            \N
# 242     \N     \N     \N          \N    \N              \N            \N
# 243     \N     \N     \N          \N     2              \N            \N
#
#      SleeveID                        Brand_Sku
# 0          \N                               \N
# 1          \N                               \N
# 2          \N                               \N
# 3          \N                          BP10001
# 4          \N                               \N
# 5          \N                          2020211
# 6          \N                               \N
# 7           2                           510661
# 8           4                        N15/11W22
# 9           2                               \N
# 10         \N                               \N
# 11         \N                               \N
# 12         \N                               \N
# 13         \N                               \N
# 14         \N                            10002
# 15          1                               \N
# 16          4                           K10000
# 17         \N                               \N
# 18         \N                               \N
# 19         \N                               \N
# 20          4                               \N
# 21         \N                               \N
# 22         \N                               \N
# 23         \N                               \N
# 24         \N                          2039211
# 25         \N                               \N
# 26         \N                               \N
# 27         \N                               \N
# 28         \N                               \N
# 29         \N                               \N
# ..        ...                              ...
# 214        \N                Anais & I_sk10000
# 215         4                               \N
# 216         4                               \N
# 217         4                    DUOOUD_008017
# 218        \N                  MISS MEME_M4047
# 219         4          RACHEL RILEY_1800001168
# 220         3                               \N
# 221         2                               \N
# 222         2       WHAT'S IN YOUR SHIRT?_0001
# 223         6                               \N
# 224         2                               \N
# 225         1                 DARCY BROWN_c18b
# 226         4                    ELAND_3420514
# 227         4            FLORENCE EISMAN_11875
# 228         1                               \N
# 229         4  BURT'S BEES KIDS_TD24655-CBR-7Y
# 230         1                  MAELI ROSE_4A04
# 231         4  BURT'S BEES KIDS_TD24649-CLH-7Y
# 232         4                               \N
# 233        \N                  MAELI ROSE_4G09
# 234        \N                      MISS B_6667
# 235        \N                Anais & I_ps10000
# 236        \N                               \N
# 237        \N                     A GATAS_n776
# 238        \N           VINEYARD VINES_3P49301
# 239        \N                 Anais & I_BP8001
# 240         2       WHAT'S IN YOUR SHIRT?_0002
# 241        \N                Anais & I_BP10003
# 242         4                Anais & I_BT10000
# 243        \N                 Anais & I_BP8000
#
# [244 rows x 37 columns]

# %%
print(len(sorted_items))
# Out:
# 15

# %%
data
# Out:
# {4: {'1': 4.0, '2': 3.0, '3': 4.0, '4': 5.0},
#  5: {'10': 5.0, '11': 5.0, '5': 5.0, '6': 5.0, '8': 5.0, '9': 4.0},
#  11: {'1': 3.0, '13': 5.0, '14': 2.0, '3': 5.0, '4': 3.0},
#  12: {'10': 4.0, '15': 5.0, '16': 5.0, '4': 3.0},
#  14: {'1': 5.0, '10': 1.0, '13': 3.0, '3': 5.0},
#  15: {'10': 5.0, '18': 3.0, '3': 5.0, '4': 5.0},
#  16: {'19': 5.0, '2': 1.0, '20': 5.0, '21': 5.0, '22': 5.0},
#  21: {'10': 5.0, '2': 5.0, '22': 5.0, '4': 5.0},
#  22: {'15': 5.0, '22': 5.0, '23': 5.0, '3': 5.0, '4': 5.0},
#  26: {'1': 5.0, '10': 4.0, '18': 2.0, '2': 5.0, '24': 5.0, '4': 1.0, '7': 5.0},
#  28: {'10': 1.0, '16': 3.0, '18': 1.0, '23': 4.0, '25': 3.0},
#  29: {'10': 5.0, '18': 1.0, '24': 3.0, '25': 5.0, '3': 5.0},
#  33: {'10': 3.0, '13': 3.0, '2': 3.0, '26': 3.0, '3': 3.0},
#  34: {'10': 3.0, '2': 3.0, '4': 3.0},
#  35: {'1': 5.0, '3': 4.0},
#  36: {'13': 5.0, '2': 3.0, '3': 5.0},
#  37: {'2': 3.0, '22': 3.0, '3': 5.0, '4': 5.0},
#  38: {'10': 5.0, '18': 1.0, '4': 5.0},
#  41: {'10': 5.0, '15': 1.0, '22': 3.0, '24': 5.0, '3': 4.0, '4': 2.0},
#  48: {'15': 3.0, '2': 5.0, '22': 3.0, '4': 4.0, '7': 5.0},
#  51: {'1': 4.0, '10': 1.0, '2': 4.0, '24': 4.0, '4': 1.0},
#  55: {'10': 3.0, '15': 4.0, '4': 5.0},
#  57: {'10': 2.0, '2': 1.0, '22': 1.0, '4': 4.0},
#  59: {'1': 5.0, '10': 2.0, '17': 1.0, '3': 5.0},
#  60: {'1': 3.0, '2': 3.0, '3': 3.0, '4': 3.0},
#  66: {'10': 2.0, '22': 3.0, '4': 1.0},
#  67: {'22': 2.0, '23': 5.0, '3': 3.0},
#  68: {'22': 4.0, '24': 2.0, '4': 1.0, '7': 4.0},
#  70: {'12': 4.0, '2': 4.0, '3': 4.0, 'x': 3.0},
#  71: {'1': 5.0, '2': 1.0, '22': 3.0, '24': 3.0, '26': 5.0, '3': 3.0, '4': 3.0},
#  72: {'10': 5.0, '2': 5.0, '3': 1.0, '4': 4.0},
#  73: {'2': 5.0, '3': 5.0, '4': 5.0},
#  92: {'10': 1.0, '18': 3.0, '24': 3.0, '4': 1.0},
#  93: {'15': 1.0, '16': 1.0, '29': 1.0, '30': 1.0},
#  94: {'1': 5.0, '2': 5.0, '3': 5.0, '4': 5.0},
#  95: {'10': 5.0, '22': 5.0, '24': 5.0, '4': 5.0}}
